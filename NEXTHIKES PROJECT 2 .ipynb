# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Phase 1: Data Acquisition

# %%
import pandas as pd

# Load Dataset_1 (assuming it's a CSV file)
dataset_1 = pd.read_csv('dataset_1 - dataset_1.csv')

# Load Dataset_2 (assuming it's an Excel file)
dataset_2 = pd.read_excel('dataset_2.xlsx')

# Load Dataset_3 (assuming it's a CSV file)
dataset_3 = pd.read_csv('dataset_3 - dataset_3.csv')

# %%
dataset_1.head()
# Out:
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0        1  01-01-2011       1   0     1   0    False        6           1
# 1        2  01-01-2011       1   0     1   1    False        6           1
# 2        3  01-01-2011       1   0     1   2    False        6           1
# 3        4  01-01-2011       1   0     1   3    False        6           1
# 4        5  01-01-2011       1   0     1   4    False        6           1
#
#    temp
# 0  0.24
# 1  0.22
# 2  0.22
# 3  0.24
# 4  0.24

# %%
dataset_2.head()
# Out:
#    Unnamed: 0  instant   atemp   hum  windspeed  casual  registered  cnt
# 0           0        1  0.2879  0.81        0.0       3          13   16
# 1           1        2  0.2727  0.80        0.0       8          32   40
# 2           2        3  0.2727  0.80        0.0       5          27   32
# 3           3        4  0.2879  0.75        0.0       3          10   13
# 4           4        5  0.2879  0.75        0.0       0           1    1

# %%
dataset_3.head()
# Out:
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0      620  29-01-2011       1   0     1   1    False        6           1
# 1      621  29-01-2011       1   0     1   2    False        6           1
# 2      622  29-01-2011       1   0     1   3    False        6           1
# 3      623  29-01-2011       1   0     1   4    False        6           1
# 4      624  29-01-2011       1   0     1   6    False        6           1
#
#    temp   atemp   hum  windspeed  casual  registered  cnt
# 0  0.22  0.2273  0.64     0.1940       0          20   20
# 1  0.22  0.2273  0.64     0.1642       0          15   15
# 2  0.20  0.2121  0.64     0.1343       3           5    8
# 3  0.16  0.1818  0.69     0.1045       1           2    3
# 4  0.16  0.1818  0.64     0.1343       0           2    2

# %%
dataset_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 610 entries, 0 to 609
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     610 non-null    int64
#  1   dteday      610 non-null    object
#  2   season      610 non-null    int64
#  3   yr          610 non-null    int64
#  4   mnth        610 non-null    int64
#  5   hr          610 non-null    int64
#  6   holiday     610 non-null    bool
#  7   weekday     610 non-null    int64
#  8   weathersit  610 non-null    int64
#  9   temp        610 non-null    float64
# dtypes: bool(1), float64(1), int64(7), object(1)
# memory usage: 43.6+ KB

# %%
dataset_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 610 entries, 0 to 609
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  610 non-null    int64
#  1   instant     610 non-null    int64
#  2   atemp       599 non-null    float64
#  3   hum         610 non-null    float64
#  4   windspeed   610 non-null    float64
#  5   casual      610 non-null    int64
#  6   registered  610 non-null    int64
#  7   cnt         610 non-null    int64
# dtypes: float64(3), int64(5)
# memory usage: 38.3 KB

# %%
dataset_3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 390 entries, 0 to 389
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     390 non-null    int64
#  1   dteday      390 non-null    object
#  2   season      390 non-null    int64
#  3   yr          390 non-null    int64
#  4   mnth        390 non-null    int64
#  5   hr          390 non-null    int64
#  6   holiday     390 non-null    bool
#  7   weekday     390 non-null    int64
#  8   weathersit  390 non-null    int64
#  9   temp        390 non-null    float64
#  10  atemp       390 non-null    float64
#  11  hum         390 non-null    float64
#  12  windspeed   390 non-null    float64
#  13  casual      390 non-null    int64
#  14  registered  390 non-null    int64
#  15  cnt         390 non-null    int64
# dtypes: bool(1), float64(4), int64(10), object(1)
# memory usage: 46.2+ KB

# %% [markdown]
# # Phase 2: Data Wrangling

# %%
# Remove duplicates
dataset_1.drop_duplicates(inplace=True)

# %%
# Remove duplicates
dataset_2.drop_duplicates(inplace=True)

# %%
# Remove duplicates
dataset_3.drop_duplicates(inplace=True)

# %%
dataset_2.drop_duplicates(inplace=True)
# Handle missing values for 'atemp' column
dataset_2['atemp'].fillna(dataset_2['atemp'].mean(), inplace=True)

# %%
# Step 2: Preprocess each dataset
def preprocess_dataset_1(dataset_1):
    dataset_1.drop_duplicates(inplace=True)
    dataset_1.fillna(dataset_1.mean(), inplace=True)
    return dataset_1
def preprocess_dataset_2(dataset_2):
    dataset_2.drop_duplicates(inplace=True)
    dataset_2.fillna(dataset_2.mean(), inplace=True)
    return dataset_2

def preprocess_dataset_3(dataset_3):
    dataset_3.drop_duplicates(inplace=True)
    dataset_3.fillna(dataset_3.mean(), inplace=True)
    return dataset_3

# %%
# Convert 'dteday' to datetime format, specifying the day-first format
dataset_3['dteday'] = pd.to_datetime(dataset_3['dteday'], dayfirst=True)

# %% [markdown]
# # Phase 3: Data Analysis

# %%
# Plotting bar plot for the `holiday` column
plt.figure(figsize=(6, 4))
sns.countplot(x='holiday', data=dataset_1)
plt.title('Holiday vs Non-Holiday')
plt.xlabel('Holiday')
plt.ylabel('Count')
plt.show()

# %%
# Plotting a histogram for the `temp` column
plt.figure(figsize=(8, 6))
sns.histplot(dataset_1['temp'], kde=True, bins=30)
plt.title('Temperature Distribution')
plt.xlabel('Temperature')
plt.ylabel('Frequency')
plt.show()

# %%
# Time Series Plot for `temp` over `dteday`
plt.figure(figsize=(12, 6))
sns.lineplot(x='dteday', y='temp', data=dataset_1)
plt.title('Temperature Over Time')
plt.xlabel('Date')
plt.ylabel('Temperature')
plt.xticks(rotation=45)
plt.show()

# %%
# Scatter plot for `temp` vs. `season`
plt.figure(figsize=(8, 6))
sns.scatterplot(x='season', y='temp', data=dataset_1)
plt.title('Temperature vs Season')
plt.xlabel('Season')
plt.ylabel('Temperature')
plt.show()

# %%
# Joint plot for `temp` and `weathersit`
sns.jointplot(x='temp', y='weathersit', data=dataset_1, kind='scatter')
plt.suptitle('Temperature vs Weather Situation', fontsize=16)
plt.show()

# %%
# Bar plot for `holiday` with `hue` as `season`
plt.figure(figsize=(8, 6))
sns.countplot(x='holiday', data=dataset_1, hue='season', palette='Set2')
plt.title('Holiday vs Non-Holiday by Season', fontsize=16)
plt.xlabel('Holiday', fontsize=12)
plt.ylabel('Count', fontsize=12)
plt.legend(title='Season')
plt.show()

# %%
# Pie plot for `season` distribution
season_counts = dataset_1['season'].value_counts()
plt.figure(figsize=(7, 7))
season_counts.plot.pie(autopct='%1.1f%%', colors=sns.color_palette('pastel', n_colors=len(season_counts)), startangle=90)
plt.title('Season Distribution')
plt.ylabel('')
plt.show()

# %%
# Scatter plot for `temp` vs `season` with `hue` as `holiday`
plt.figure(figsize=(8, 6))
sns.scatterplot(x='season', y='temp', data=dataset_1, hue='holiday', palette='coolwarm', s=100, edgecolor='black')
plt.title('Temperature vs Season by Holiday', fontsize=16)
plt.xlabel('Season', fontsize=12)
plt.ylabel('Temperature', fontsize=12)
plt.show()

# %%
# Line plot for `temp` over time with `hue` as `season`
plt.figure(figsize=(12, 6))
sns.lineplot(x='dteday', y='temp', data=dataset_1, hue='season', palette='coolwarm', linewidth=2)
plt.title('Temperature Over Time by Season', fontsize=16)
plt.xlabel('Date', fontsize=12)
plt.ylabel('Temperature', fontsize=12)
plt.xticks(rotation=45)
plt.show()

# %%
# Joint plot for `temp` and `weathersit` with `hue` as `season`
sns.jointplot(x='temp', y='weathersit', data=dataset_1, kind='scatter', hue='season', palette='muted')
plt.suptitle('Temperature vs Weather Situation by Season', fontsize=16)
plt.show()

# %%
# Bar plot for casual and registered users by season with hue
plt.figure(figsize=(8, 6))
sns.barplot(x=['Casual Users', 'Registered Users'], y=[dataset_2['casual'].sum(), dataset_2['registered'].sum()], hue=['Casual', 'Registered'], palette='Set1')
plt.title('Total Casual vs Registered Users by Season', fontsize=16)
plt.ylabel('Count', fontsize=12)
plt.show()

# %%
# Pie plot for casual and registered users
user_counts = [dataset_2['casual'].sum(), dataset_2['registered'].sum()]
labels = ['Casual Users', 'Registered Users']
colors = sns.color_palette('Set2', n_colors=2)
plt.figure(figsize=(7, 7))
plt.pie(user_counts, labels=labels, autopct='%1.1f%%', startangle=90, colors=colors)
plt.title('Casual vs Registered Users')
plt.show()

# %%
# Line plot for `cnt` over `dteday` with `hue` as `season`
plt.figure(figsize=(12, 6))
sns.lineplot(x='dteday', y='cnt', data=dataset_3, hue='season', palette='muted', linewidth=2)
plt.title('Total Count of Users Over Time by Season', fontsize=16)
plt.xlabel('Date', fontsize=12)
plt.ylabel('Total Count', fontsize=12)
plt.xticks(rotation=45)
plt.show()

# %%
# Joint plot for `hum` and `cnt` with `hue` as `season`
sns.jointplot(x='hum', y='cnt', data=dataset_3, kind='scatter', hue='season', palette='magma')
plt.suptitle('Humidity vs Total Count by Season', fontsize=16)
plt.show()

# %%
# Merge dataset_1 and dataset_2 on the 'instant' column
new_dataset = pd.merge(dataset_1, dataset_2, on='instant', how='inner')

# Display the merged dataset
new_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 610 entries, 0 to 609
# Data columns (total 17 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     610 non-null    int64
#  1   dteday      610 non-null    object
#  2   season      610 non-null    int64
#  3   yr          610 non-null    int64
#  4   mnth        610 non-null    int64
#  5   hr          610 non-null    int64
#  6   holiday     610 non-null    bool
#  7   weekday     610 non-null    int64
#  8   weathersit  610 non-null    int64
#  9   temp        610 non-null    float64
#  10  Unnamed: 0  610 non-null    int64
#  11  atemp       610 non-null    float64
#  12  hum         610 non-null    float64
#  13  windspeed   610 non-null    float64
#  14  casual      610 non-null    int64
#  15  registered  610 non-null    int64
#  16  cnt         610 non-null    int64
# dtypes: bool(1), float64(4), int64(11), object(1)
# memory usage: 77.0+ KB

# %%
# Drop the unnecessary columns: 'Unnamed: 0', 'yr', and 'mnth'
new_dataset = new_dataset.drop(columns=['Unnamed: 0', 'yr', 'mnth'])

# Display the cleaned dataset
new_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 610 entries, 0 to 609
# Data columns (total 14 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     610 non-null    int64
#  1   dteday      610 non-null    object
#  2   season      610 non-null    int64
#  3   hr          610 non-null    int64
#  4   holiday     610 non-null    bool
#  5   weekday     610 non-null    int64
#  6   weathersit  610 non-null    int64
#  7   temp        610 non-null    float64
#  8   atemp       610 non-null    float64
#  9   hum         610 non-null    float64
#  10  windspeed   610 non-null    float64
#  11  casual      610 non-null    int64
#  12  registered  610 non-null    int64
#  13  cnt         610 non-null    int64
# dtypes: bool(1), float64(4), int64(8), object(1)
# memory usage: 62.7+ KB

# %%
# Convert 'dteday' to datetime format, specifying the day-first format
new_dataset['dteday'] = pd.to_datetime(new_dataset['dteday'], dayfirst=True)

# Check the updated data types
print(new_dataset.dtypes)
# Out:
# instant                int64
# dteday        datetime64[ns]
# season                 int64
# hr                     int64
# holiday                 bool
# weekday                int64
# weathersit             int64
# temp                 float64
# atemp                float64
# hum                  float64
# windspeed            float64
# casual                 int64
# registered             int64
# cnt                    int64
# dtype: object

# %%
# Remove duplicate rows
new_dataset = new_dataset.drop_duplicates()

# Display the cleaned dataset info
new_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 610 entries, 0 to 609
# Data columns (total 14 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     610 non-null    int64
#  1   dteday      610 non-null    datetime64[ns]
#  2   season      610 non-null    int64
#  3   hr          610 non-null    int64
#  4   holiday     610 non-null    bool
#  5   weekday     610 non-null    int64
#  6   weathersit  610 non-null    int64
#  7   temp        610 non-null    float64
#  8   atemp       610 non-null    float64
#  9   hum         610 non-null    float64
#  10  windspeed   610 non-null    float64
#  11  casual      610 non-null    int64
#  12  registered  610 non-null    int64
#  13  cnt         610 non-null    int64
# dtypes: bool(1), datetime64[ns](1), float64(4), int64(8)
# memory usage: 62.7 KB

# %%
# Check basic information about the dataset
new_dataset.info()

# Check the first few rows of the dataset
new_dataset.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 610 entries, 0 to 609
# Data columns (total 14 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     610 non-null    int64
#  1   dteday      610 non-null    datetime64[ns]
#  2   season      610 non-null    int64
#  3   hr          610 non-null    int64
#  4   holiday     610 non-null    bool
#  5   weekday     610 non-null    int64
#  6   weathersit  610 non-null    int64
#  7   temp        610 non-null    float64
#  8   atemp       610 non-null    float64
#  9   hum         610 non-null    float64
#  10  windspeed   610 non-null    float64
#  11  casual      610 non-null    int64
#  12  registered  610 non-null    int64
#  13  cnt         610 non-null    int64
# dtypes: bool(1), datetime64[ns](1), float64(4), int64(8)
# memory usage: 62.7 KB
#    instant     dteday  season  hr  holiday  weekday  weathersit  temp   atemp  \
# ...

# %%
# Summary statistics for numerical columns
new_dataset.describe()

# Summary statistics for categorical columns
new_dataset.describe(include=['object', 'bool'])
# Out:
#        holiday
# count      610
# unique       2
# top      False
# freq       586

# %%
# Check for missing values
missing_values = new_dataset.isnull().sum()
print("Missing values per column:\n", missing_values)
# Out:
# Missing values per column:
#  instant       0
# dteday        0
# season        0
# hr            0
# holiday       0
# weekday       0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %%
# Correlation matrix
plt.figure(figsize=(10, 8))
correlation_matrix = new_dataset.corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', cbar=True)
plt.title('Correlation Matrix', fontsize=16)
plt.show()

# %%
# Histograms for continuous variables
new_dataset.hist(figsize=(12, 10), bins=20, edgecolor='black')
plt.suptitle('Histograms for Continuous Features', fontsize=16)
plt.show()

# Count plot for categorical variables
plt.figure(figsize=(10, 6))
sns.countplot(x='season', data=new_dataset, palette='Set1')
plt.title('Season Distribution', fontsize=16)
plt.show()

# Count plot for holidays
plt.figure(figsize=(10, 6))
sns.countplot(x='holiday', data=new_dataset, palette='Set2')
plt.title('Holiday Distribution', fontsize=16)
plt.show()

# Count plot for weather situation
plt.figure(figsize=(10, 6))
sns.countplot(x='weathersit', data=new_dataset, palette='Set3')
plt.title('Weather Situation Distribution', fontsize=16)
plt.show()

# %%
# Scatter plot for temp vs windspeed with hue as season
plt.figure(figsize=(8, 6))
sns.scatterplot(x='temp', y='windspeed', data=new_dataset, hue='season', palette='viridis', s=100, edgecolor='black')
plt.title('Temperature vs Windspeed by Season', fontsize=16)
plt.xlabel('Temperature', fontsize=12)
plt.ylabel('Windspeed', fontsize=12)
plt.show()

# Bar plot for average count by season
plt.figure(figsize=(8, 6))
sns.barplot(x='season', y='cnt', data=new_dataset, palette='coolwarm')
plt.title('Average Count by Season', fontsize=16)
plt.xlabel('Season', fontsize=12)
plt.ylabel('Average Count', fontsize=12)
plt.show()

# %%
# Joint plot for temp vs cnt
sns.jointplot(x='temp', y='cnt', data=new_dataset, kind='scatter', color='green', height=8)
plt.suptitle('Temperature vs Count', fontsize=16)
plt.show()

# %%
# Create a stacked bar plot to show the distribution of casual and registered users across seasons
season_counts = new_dataset.groupby(['season'])[['casual', 'registered']].sum()
season_counts.plot(kind='bar', stacked=True, figsize=(10, 6), color=['orange', 'purple'])
plt.title('Stacked Bar Plot of Casual and Registered Users by Season', fontsize=16)
plt.xlabel('Season', fontsize=12)
plt.ylabel('Count', fontsize=12)
plt.show()

# %%
# Pie chart for season distribution
season_pie = new_dataset['season'].value_counts()
plt.figure(figsize=(8, 6))
season_pie.plot(kind='pie', autopct='%1.1f%%', startangle=90, colors=['lightblue', 'lightgreen', 'lightcoral', 'lightskyblue'])
plt.title('Season Distribution', fontsize=16)
plt.ylabel('')
plt.show()

# Pie chart for weather situation distribution
weathersit_pie = new_dataset['weathersit'].value_counts()
plt.figure(figsize=(8, 6))
weathersit_pie.plot(kind='pie', autopct='%1.1f%%', startangle=90, colors=['#f1c40f', '#e74c3c', '#2ecc71'])
plt.title('Weather Situation Distribution', fontsize=16)
plt.ylabel('')
plt.show()

# %%
new_dataset.info()
dataset_3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 610 entries, 0 to 609
# Data columns (total 14 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     610 non-null    int64
#  1   dteday      610 non-null    datetime64[ns]
#  2   season      610 non-null    int64
#  3   hr          610 non-null    int64
#  4   holiday     610 non-null    bool
#  5   weekday     610 non-null    int64
#  6   weathersit  610 non-null    int64
#  7   temp        610 non-null    float64
#  8   atemp       610 non-null    float64
#  9   hum         610 non-null    float64
#  10  windspeed   610 non-null    float64
#  11  casual      610 non-null    int64
#  12  registered  610 non-null    int64
#  13  cnt         610 non-null    int64
# dtypes: bool(1), datetime64[ns](1), float64(4), int64(8)
# memory usage: 62.7 KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 390 entries, 0 to 389
# Data columns (total 16 columns):
# ...

# %%
# Rename columns in dataset_1 and dataset_2
dataset_1.rename(columns={
    'season': 'season', 
    'hr': 'hr', 
    'holiday': 'holiday',
    'weekday': 'weekday',
    'weathersit': 'weathersit',
    'temp': 'temp',
    'atemp': 'atemp',
    'hum': 'hum',
    'windspeed': 'windspeed',
    'casual': 'casual',
    'registered': 'registered',
    'cnt': 'cnt'
}, inplace=True)

dataset_2.rename(columns={
    'season': 'season', 
    'hr': 'hr', 
    'holiday': 'holiday',
    'weekday': 'weekday',
    'weathersit': 'weathersit',
    'temp': 'temp',
    'atemp': 'atemp',
    'hum': 'hum',
    'windspeed': 'windspeed',
    'casual': 'casual',
    'registered': 'registered',
    'cnt': 'cnt'
}, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 2
#       1 # Rename columns in dataset_1 and dataset_2
# ----> 2 dataset_1.rename(columns={
#       3     'season': 'season',
#       4     'hr': 'hr',
#       5     'holiday': 'holiday',
#       6     'weekday': 'weekday',
#       7     'weathersit': 'weathersit',
#       8     'temp': 'temp',
#       9     'atemp': 'atemp',
#      10     'hum': 'hum',
#      11     'windspeed': 'windspeed',
#      12     'casual': 'casual',
#      13     'registered': 'registered',
#      14     'cnt': 'cnt'
#      15 }, inplace=True)
#      17 dataset_2.rename(columns={
#      18     'season': 'season',
#      19     'hr': 'hr',
#    (...)
#      29     'cnt': 'cnt'
#      30 }, inplace=True)
#
# NameError: name 'dataset_1' is not defined

# %%
# Drop one of the 'dteday' columns (since you only need one)
final_dataset.drop(columns=['dteday_y'], inplace=True)

# Optionally, rename the remaining 'dteday' column if necessary
final_dataset.rename(columns={'dteday_x': 'dteday'}, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[44], line 2
#       1 # Drop one of the 'dteday' columns (since you only need one)
# ----> 2 final_dataset.drop(columns=['dteday_y'], inplace=True)
#       4 # Optionally, rename the remaining 'dteday' column if necessary
#       5 final_dataset.rename(columns={'dteday_x': 'dteday'}, inplace=True)
#
# NameError: name 'final_dataset' is not defined

# %%
# Merge the two datasets based on 'instant' column
final_dataset = pd.merge(new_dataset, dataset_3, on='instant', how='outer')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 2
#       1 # Merge the two datasets based on 'instant' column
# ----> 2 final_dataset = pd.merge(new_dataset, dataset_3, on='instant', how='outer')
#
# NameError: name 'pd' is not defined

# %%
final_dataset.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 final_dataset.info()
#
# NameError: name 'final_dataset' is not defined
